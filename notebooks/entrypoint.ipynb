# %%
import torch
from src.entrypoint import build_sample_batch

print('torch:', torch.__version__)
batch = build_sample_batch(batch_size=2, channels=3, height=128, width=128)
print('batch shape:', tuple(batch.shape))
# Out:
# torch: 2.5.0a0+872d972e41.nv24.08
# batch shape: (2, 3, 128, 128)
